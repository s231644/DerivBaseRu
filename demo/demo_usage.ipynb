# %% [markdown]
# # DerivBase.Ru Demo Usage

# %% [markdown]
# This is a demo notebook which shows how to use a library **DerivBase.Ru**.

# %% [markdown]
# First create an object of class **Derivation**.
#
# A parameter **use_guesser** is boolean. By default, **use_guesser = True**. If **use_guesser = True**, we import a module called **ZaliznyakGuesser** to guess additional tags for a given word.

# %%
import sys
sys.path.append("../") # go to parent dir

from src.Derivation import Derivation
derivator = Derivation(use_guesser=True)

# %% [markdown]
# Let us look how **ZaliznyakGuesser** works.

# %%
derivator.tag_guesser.guess(word='конь', pos='noun')
# Out:
# [{'gender': ['m'], 'number': ['s'], 'inflect_type': ['2']},
#  {'gender': ['f'], 'number': ['s'], 'inflect_type': ['8']}]

# %%
derivator.tag_guesser.guess(word='красивый', pos='adj')
# Out:
# [{'gender': ['m'], 'form': ['full'], 'inflect_type': ['1']}]

# %%
derivator.tag_guesser.guess(word='желать', pos='verb')
# Out:
# [{'inflect_type': ['1']}]

# %% [markdown]
# To correctly determine an inflectional type of a verb, one needs three wordforms: infinitive, 1st person and 3rd person.
# If only an infinitive stated, we use **pymorphy2** to inflect it.

# %%
len(derivator.rules)
# Out:
# 833

# %%
derivator.rules[::100]
# Out:
# [rule285(adj + ик/ник/евик -> noun)	(-ик),
#  rule223(verb + аль -> noun)	(-аль),
#  rule283(verb + ант/емент -> noun)	(-ант),
#  rule379(noun + ай -> noun)	(-ай),
#  rule580(noun + 0 -> noun)	(-0),
#  rule642(noun + ист(ый) -> adj)	(-ист-),
#  rule807(adj + ова(ть) -> verb)	(-ова-),
#  rule734(под + noun + н1(ый) -> adj)	(-),
#  rule887(пере + noun + и1(ть) -> verb)	(-)]

# %%
rule930 = derivator.rules_dict['rule930(verb + ся -> verb)']

# %%
rule930.apply('смотреть')
# Out:
# {'смотреться'}

# %%
res = derivator.derive('смотреть', pos_b='verb', is_extended=False, use_rare=True)

# %%
print(res)
# Out:
# {'посматрять', 'несмотретельный', 'смотрчивый', 'рассмотрывать', 'взосмотреться', 'смотрщик', 'диссмотреть', 'восмотреться', 'высмотрывать', 'смотрять', 'взосмотрнуть', 'засмотрнуть', 'сматрать', 'всмотреть', 'высмотривать', 'подосматрять', 'взосмотреть', 'насмотреть', 'смотрельня', 'насматрять', 'подосмотривать', 'ссмотрнуть', 'смотрельный', 'смотретельный', 'пересмотривать', 'разосмотреть', 'насмотрять', 'отсматривать', 'пересмотриваться', 'осмотрнуть', 'отсмотреться', 'смотруха', 'посматрывать', 'посматрать', 'смотрелый', 'обосмотреться', 'отосмотривать', 'восмотреть', 'посмотривать', 'бессмотрительный', 'всмотрку', 'смотрач', 'сматрять', 'отсмотрывать', 'вссмотреться', 'смотрелец', 'вссмотрнуть', 'смотревый', 'подсмотрять', 'присмотрать', 'несмотримый', 'насмотрывать', 'разосмотрывать', 'присматривать', 'пересмотраться', 'усмотрев', 'разосматрывать', 'посмотрать', 'рассмотрать', 'смотритель', 'высмотреть', 'пересматрывать', 'отосматрять', 'подсмотрать', 'рассматривать', 'высматривать', 'сосмотреть', 'отосмотрать', 'разосмотривать', 'смотрибельный', 'просмотреть', 'отсмотрать', 'смотровый', 'бессмотреть', 'обосмотреть', 'ресмотреть', 'засмотреться', 'смотриха', 'присмотрев', 'просмотреться', 'смотрок', 'воссмотреть', 'смотрчик', 'дезсмотреть', 'насмотр', 'рассмотривать', 'рассматрять
> noun)': {'смотрелка'}, 'rule230(verb + л(а)/л(о) -> noun)': {'смотрело', 'смотрела'}, 'rule231(verb + к(а)/ушк(а)/шк(а) -> noun)': {'смотрушка', 'смотрка'}, 'rule234(verb + ух(а)/их(а) -> noun)': {'смотруха'}, 'rule237(verb + ул(я) -> noun)': {'смотрюля'}, 'rule241(verb + льн(я) -> noun)': {'смотрельня'}, 'rule252(verb + имость -> noun)': {'смотримость'}, 'rule253(verb + ённость/нность/тость -> noun)': {'смотренность', 'смотрённость'}, 'rule256(verb + ниj(е) -> noun)': {'смотрение', 'смотренье'}, 'rule262(verb + к(а)/овк(а)/ёжк(а) -> noun)': {'смотрка'}, 'rule265(verb + от(а) -> noun)': {'смотрота'}, 'rule266(verb + б(а)/об(а) -> noun)': {'смотрьба'}, 'rule267(verb + н(я)/отн(я)/овн(я) -> noun)': {'смотрня'}, 'rule269(verb + ёж -> noun)': {'смотрёж'}, 'rule270(verb + ок -> noun)': {'смотрок'}, 'rule279(verb + ух(а)/их(а) -> noun)': {'смотруха', 'смотриха'}, 'rule281(verb + к(и)/лк(и)/шк(и)/ушк(и) -> noun)': {'смотрелки'}, 'rule282(verb + ин(ы) -> noun)': {'смотрины'}, 'rule446(verb + 0m2 -> noun)': {'смотр'}, 'rule454(verb + 0f3 -> noun)': {'смотрь'}, 'rule651(verb + льн(ый) -> adj)': {'смотрельный'}, 'rule652(verb + тельн(ый)/ительн(ый) -> adj)': {'смотретельный', 'смотрительный'}, 'rule653(verb + абельн(ый)/ибельн(ый) -> adj)': {'смотрибельный'}, 'rule654(verb + ов(ый) -> adj)': {'смотревый', 'смотревой', 'смотровой', 'смотровый'}, 'rule656(verb + к(ий) -> adj)': {'смотркий'}, 'rule657(verb + ом(ый)/им(ый) -> adj)': {'смотримый'}, 'rule660(verb + уч/ач(ий) -> adj)': {'смотрячий', 'смотрючий'}, 'rule661(verb + лив(ый)/чив(ый)/ив(ый) -> adj)': {'смотрчивый', 'смотрливый'}, 'rule662(verb + л(ый) -> adj)': {'смотрелый'}, 'rule663(verb + ен(ый)/н2(ый)/т(ый) -> adj)': {'смотреный'}, 'rule854(без + verb -> verb)': {'безосмотреть', 'бессмотреть'}, 'rule855(в + verb -> verb)': {'восмотреть', 'всмотреть'}, 'rule855(вз + verb -> verb)': {'вссмотреть', 'взосмотреть'}, 'rule856(воз + verb -> verb)': {'возосмотреть', 'воссмотреть'}, 'rule857(вы + verb -> verb)': {'высмотреть'}, 'rule858(де + verb -> verb)': {'десмотреть', 'дезсмотреть'}, 'rule859(дис + verb -> verb)': {'диссмотреть'}, 'rule860(до + verb -> verb)': {'досмотреть'}, 'rule861(за + verb -> verb)': {'засмотреть'}, 'rule862(из + verb -> verb)': {'иссмотреть', 'изосмотреть'}, 'rule863(на + verb -> verb)': {'насмотреть'}, 'rule864(над + verb -> verb)': {'надосмотреть', 'надсмотреть'}, 'rule865(недо + verb -> verb)': {'недосмотреть'}, 'rule866(низ + verb -> verb)': {'низосмотреть', 'ниссмотреть'}, 'rule867(о + verb -> verb)': {'осмотреть'}, 'rule868(об + verb -> verb)': {'обосмотреть', 'обсмотреть'}, 'rule869(от + verb -> verb)': {'отосмотреть', 'отсмотреть'}, 'rule870(пере + verb -> verb)': {'пересмотреть'}, 'rule871(по + verb -> verb)': {'посмотреть'}, 'rule872(под + verb -> verb)': {'подсмотреть', 'подосмотреть'}, 'rule873(пре + verb -> verb)': {'пресмотреть'}, 'rule874(пред + verb -> verb)': {'предсмотреть', 'предосмотреть'}, 'rule875(при + verb -> verb)': {'присмотреть'}, 'rule876(про + verb -> verb)': {'просмотреть'}, 'rule877(раз + verb -> verb)': {'рассмотреть', 'разосмотреть'}, 'rule878(ре + verb -> verb)': {'ресмотреть'}, 'rule879(с + verb -> verb)': {'ссмотреть', 'сосмотреть'}, 'rule880(со2 + verb -> verb)': {'сосмотреть'}, 'rule881(у + verb -> verb)': {'усмотреть'}, 'rule836(verb + ну2(ть) -> verb)': {'смотрнуть'}, 'rule840(verb + ану(ть) -> verb)': {'смотрануть'}, 'rule842(verb + ива(ть)/ва(ть)/а3(ть) -> verb)': {'смотрывать', 'смотривать', 'сматрять', 'сматривать', 'смотрять', 'смотрать', 'сматрать', 'сматрывать ...

# %%
from collections import defaultdict

short_rules = set()
stats = defaultdict(int)

for rule in derivator.rules:
    if rule.name.split(':')[0] not in short_rules:
        stats[rule.pos_b, rule.pos_a, rule.info] += 1
        short_rules.add(rule.name.split(':')[0])

# %%
stats
# Out:
# defaultdict(int,
#             {('adj', 'noun', 'SFX'): 84,
#              ('adj', 'noun', '0SFX'): 2,
#              ('adj', 'noun', 'CONV'): 1,
#              ('part', 'noun', 'CONV'): 1,
#              ('verb', 'noun', 'SFX'): 133,
#              ('noun', 'noun', 'SFX'): 179,
#              ('noun', 'noun', 'INTERFIX'): 1,
#              ('noun', 'noun', 'INFL'): 1,
#              ('noun', 'noun', 'PFX'): 38,
#              ('adj', 'adj', 'PFX'): 40,
#              ('noun', 'adj', 'SFX'): 31,
#              ('adj', 'adj', 'SFX'): 25,
#              ('comp', 'adj', 'SFX'): 1,
#              ('adj', 'adj', 'INTERFIX'): 1,
#              ('verb', 'adj', 'SFX'): 25,
#              ('noun', 'verb', 'SFX'): 6,
#              ('verb', 'verb', 'PFX'): 30,
#              ('adj', 'verb', 'SFX'): 7,
#              ('verb', 'verb', 'SFX'): 8,
#              ('verb', 'verb', 'PTFX'): 1,
#              ('adv', 'adv', 'SFX'): 5,
#              ('adj', 'adv', 'SFX'): 10,
#              ('adv', 'adv', 'PFX'): 12,
#              ('verb', 'adv', 'SFX'): 7,
#              ('noun', 'adv', 'SFX'): 3,
#              ('num', 'num', 'INTERFIX'): 1,
#              ('adj', 'noun', 'PFX,SFX'): 4,
#              ('verb', 'noun', 'PFX,SFX'): 4,
#              ('noun', 'noun', 'PFX,SFX'): 18,
#              ('verb', 'adj', 'PFX,SFX'): 8,
#              ('adj', 'adj', 'PFX,SFX'): 1,
#              ('noun', 'adj', 'PFX,SFX'): 29,
#              ('adj', 'verb', 'PFX,SFX'): 21,
#              ('adj', 'verb', 'SFX,PTFX'): 1,
#              ('verb', 'verb', 'PFX,SFX'): 35,
#              ('verb', 'verb', 'PFX,PTFX'): 16,
#              ('verb', 'verb', 'PFX,SFX,PTFX'): 1,
#              ('noun', 'verb', 'PFX,SFX'): 21,
#              ('noun', 'verb', 'SFX,PTFX'): 1,
#              ('noun', 'verb', 'PFX,SFX,PTFX'): 2,
#              ('verb', 'adv', 'PFX,SFX'): 4,
#              ('noun', 'adv', 'PFX,SFX'): 3,
#              ('adj', 'adv', 'PFX,SFX'): 9,
#              ('adv', 'adv', 'PFX,SFX'): 1})
